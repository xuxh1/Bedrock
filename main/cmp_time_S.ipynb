# %%
import os
import numpy as np
import xarray as xr
import pandas as pd
import netCDF4 as nc
import geopandas as gpd
import rioxarray as rxr
from myfunc import timer
from myfunc import DirMan
from myfunc import load_and_flatten_data
import config

# configuration
resolution = "0p1"
# resolution = "500"
region = [-180,180,-60,90]
data_path = f'/tera04/zhwei/xionghui/bedrock/run/{resolution}/'
post_data_path = '/tera04/zhwei/xionghui/bedrock/'
shp_path = '/tera04/zhwei/xionghui/bedrock/Shp/'
fig_path = f'/home/xuxh22/stu01/Bedrock/fig/{resolution}/'
path = '/home/xuxh22/stu01/Bedrock/'

if resolution == "0p1":
    size = 0.1
elif resolution == "500":
    size = 0.0005

dir_man = DirMan(data_path)
dir_man.enter()

os.makedirs(f'{data_path}/csv', exist_ok=True)

# area_sum = 19.925158940748766
# Out:
# Entered /tera04/zhwei/xionghui/bedrock/run/0p1/

# %%
# df = pd.DataFrame()

# with nc.Dataset('mask1234.nc4') as dataset:
#     lat = dataset['lat'][:].flatten()
#     lon = dataset['lon'][:].flatten()
#     df['lat'] = np.repeat(lat, len(lon))
#     df['lon'] = np.tile(lon, len(lat))

# file_variable_list = [
#     ('mask1234', 'Band1'),
#     ('Sbedrock', 'Sbedrock'),
#     ('Area', 'area'),

#     ('S_Frequency_mean', 'Frequency'),
#     ('S_Frequency_max', 'Frequency'),
#     ('S_Frequency_max_sub_mean', 'Frequency'),
#     ('S_CY', 'Cross_Year', 0)
# ]

# for entry in file_variable_list:
#     file = entry[0]
#     variable_name = entry[1]  
#     index = entry[2:] if len(entry) > 2 else None  
#     if index:
#         df[file] = load_and_flatten_data(file, variable_name, index[0])
#     else:
#         df[file] = load_and_flatten_data(file, variable_name)


# df = df.dropna()
# df = df[df['Sbedrock'] > 0]
# df = df[df['mask1234'] == 1]

# sfmax = df['S_Frequency_mean'].mean()
# sfmean = df['S_Frequency_max'].mean()
# sfmsm = df['S_Frequency_max_sub_mean'].mean()
# scy = df['S_CY'].mean()


# print(sfmax)
# print(sfmean)
# print(sfmsm)
# print(scy)
# print((df['Area'].sum()/1e12))


# df.drop(labels='mask1234',axis=1,inplace=True)
# with open('csv/Global_S_year_Frequency.csv','w') as f:
#     df.to_csv(f)
# df

# %%
# df = pd.DataFrame()

# with nc.Dataset('mask1234.nc4') as dataset:
#     lat = dataset['lat'][:].flatten()
#     lon = dataset['lon'][:].flatten()
#     df['lat'] = np.repeat(lat, len(lon))
#     df['lon'] = np.tile(lon, len(lat))

# file_variable_list = [
#     ('mask1234', 'Band1'),
#     ('Sbedrock', 'Sbedrock'),
#     ('Area', 'area'),

#     ('S_time_max_duration','Duration'),
#     ('S_time_mean_duration', 'Duration'),
#     ('S_sum_Frequency', 'Frequency'),
#     ('S_sum_duration', 'Duration'),
# ]

# for entry in file_variable_list:
#     file = entry[0]
#     variable_name = entry[1]  
#     index = entry[2:] if len(entry) > 2 else None  
#     if index:
#         df[file] = load_and_flatten_data(file, variable_name, index[0])
#     else:
#         df[file] = load_and_flatten_data(file, variable_name)


# df = df.dropna()
# df = df[df['Sbedrock'] > 0]
# df = df[df['mask1234'] == 1]

# sfmaxd = df['S_time_max_duration'].mean()
# sfmeand = df['S_time_mean_duration'].mean()
# ssf = df['S_sum_Frequency'].mean()
# ssd = df['S_sum_duration'].mean()


# print(sfmaxd)
# print(sfmeand)
# print(ssf)
# print(ssd)
# print((df['Area'].sum()/1e12))


# df.drop(labels='mask1234',axis=1,inplace=True)
# with open('csv/Global_S_time.csv','w') as f:
#     df.to_csv(f)
# df

# %%
# df = pd.DataFrame()

# with nc.Dataset('mask1234.nc4') as dataset:
#     lat = dataset['lat'][:].flatten()
#     lon = dataset['lon'][:].flatten()
#     df['lat'] = np.repeat(lat, len(lon))
#     df['lon'] = np.tile(lon, len(lat))

# file_variable_list = [
#     ('mask1234', 'Band1'),
#     ('Sbedrock', 'Sbedrock'),
#     ('Area', 'area'),

#     ('S_Duration_mean','Duration'),
#     ('S_Duration_max', 'Duration'),
#     ('S_Duration_max_sub_mean', 'Duration'),
# ]

# for entry in file_variable_list:
#     file = entry[0]
#     variable_name = entry[1]  
#     index = entry[2:] if len(entry) > 2 else None  
#     if index:
#         df[file] = load_and_flatten_data(file, variable_name, index[0])
#     else:
#         df[file] = load_and_flatten_data(file, variable_name)


# df = df.dropna()
# df = df[df['Sbedrock'] > 0]
# df = df[df['mask1234'] == 1]

# sdmean = df['S_Duration_mean'].mean()
# sdmax = df['S_Duration_max'].mean()
# sdmsm = df['S_Duration_max_sub_mean'].mean()



# print(sdmean)
# print(sdmax)
# print(sdmsm)
# print((df['Area'].sum()/1e12))


# df.drop(labels='mask1234',axis=1,inplace=True)
# with open('csv/Global_S_year_Duration.csv','w') as f:
#     df.to_csv(f)
# df

# %%
# df = pd.DataFrame()

# with nc.Dataset('mask1234.nc4') as dataset:
#     lat = dataset['lat'][:].flatten()
#     lon = dataset['lon'][:].flatten()
#     df['lat'] = np.repeat(lat, len(lon))
#     df['lon'] = np.tile(lon, len(lat))

# file_variable_list = [
#     ('mask1234', 'Band1'),
#     ('Sbedrock', 'Sbedrock'),
#     ('Area', 'area'),

#     ('S_FD_mean','First_Day'),
#     ('S_FD_max', 'First_Day'),
#     ('S_FD_max_sub_mean', 'First_Day'),
# ]

# for entry in file_variable_list:
#     file = entry[0]
#     variable_name = entry[1]  
#     index = entry[2:] if len(entry) > 2 else None  
#     if index:
#         df[file] = load_and_flatten_data(file, variable_name, index[0])
#     else:
#         df[file] = load_and_flatten_data(file, variable_name)


# df = df.dropna()
# df = df[df['Sbedrock'] > 0]
# df = df[df['mask1234'] == 1]

# sdmean = df['S_FD_mean'].mean()
# sdmax = df['S_FD_max'].mean()
# sdmsm = df['S_FD_max_sub_mean'].mean()



# print(sdmean)
# print(sdmax)
# print(sdmsm)
# print((df['Area'].sum()/1e12))


# df.drop(labels='mask1234',axis=1,inplace=True)
# with open('csv/Global_S_year_FD.csv','w') as f:
#     df.to_csv(f)
# df
