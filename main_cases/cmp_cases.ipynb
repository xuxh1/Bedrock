# %%
import os
import numpy as np
import xarray as xr
import pandas as pd
import netCDF4 as nc
import geopandas as gpd
import rioxarray as rxr
from myfunc import timer
from myfunc import DirMan
from myfunc import load_and_flatten_data
import config

resolution     = config.resolution
region         = config.region
data_path      = config.data_path
post_data_path = config.post_data_path
shp_path       = config.shp_path
fig_path       = config.fig_path

dir_man = DirMan(data_path)
dir_man.enter()

os.makedirs(f'{data_path}/csv', exist_ok=True)

casename1 = 'bedrock_1'
path1 = f'{data_path}/cases/{casename1}/'
casename2 = 'bedrock_2'
path2 = f'{data_path}/cases/{casename2}/'
casename3 = 'bedrock_3'
path3 = f'{data_path}/cases/{casename3}/'
# Out:
# Entered /tera11/zhwei/students/Xionghui/data/run/500/

# %%
df = pd.DataFrame()

with nc.Dataset(f'Sbedrock.nc4') as dataset:
    lat = dataset['lat'][:].flatten()
    lon = dataset['lon'][:].flatten()
    df['lat'] = np.repeat(lat, len(lon))
    df['lon'] = np.tile(lon, len(lat))

file_variable_list = [
    (f'mask123', 'Band1'),
    (f'Sbedrock', 'Sbedrock'),
    (f'Area', 'area'),

    (f'{path1}Sbedrock_mean', 'Sr'),
    (f'{path2}Sbedrock_mean', 'Sr'),
    (f'{path3}Sbedrock_mean', 'Sr'),
]

for entry in file_variable_list:
    file = entry[0]
    variable_name = entry[1]  
    index = entry[2:] if len(entry) > 2 else None  

    # print(f"File: {file}, Variable: {variable_name}, Index: {index}")
    if index:
        df[file] = load_and_flatten_data(file, variable_name, index[0])
    else:
        df[file] = load_and_flatten_data(file, variable_name)


df = df.dropna()
df = df[df['Sbedrock'] > 0]
df = df[df['mask123'] == 1]
df.drop(labels='mask123',axis=1,inplace=True)

print(df[f'{path1}Sbedrock_mean'].mean())
print(df[f'{path2}Sbedrock_mean'].mean())
print(df[f'{path3}Sbedrock_mean'].mean())
print(df['Sbedrock'].mean())

with open(f'csv/Global_cases_sb.csv','w') as f:
    df.to_csv(f)
df
# Out:
# 124.44057
# 26.9599
# 64.735886
# 125.557434
#                   lat        lon   Sbedrock           Area  \
# 720603040  -55.247915 -67.331244  40.948978  122369.355140
# 720603041  -55.247915 -67.327077  37.316536  122369.355140
# 720603042  -55.247915 -67.322911  33.684097  122369.355140
# 720603043  -55.247915 -67.318744  30.051655  122369.355140
# 720603044  -55.247915 -67.314577  26.419214  122369.355140
# ...               ...        ...        ...            ...
# 3579846847  82.639592 -31.468742  33.762409   27501.828156
# 3579846848  82.639592 -31.464576  33.865299   27501.828156
# 3579846849  82.639592 -31.460409  33.968189   27501.828156
# 3579846850  82.639592 -31.456242  34.071079   27501.828156
# 3579846851  82.639592 -31.452076  34.173969   27501.828156
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_1/Sbedrock_mean  \
# 720603040                                          125.608299
# 720603041                                          125.885208
# 720603042                                          126.162117
# 720603043                                          126.439018
# 720603044                                          126.715927
# ...                                                       ...
# 3579846847                                         323.541229
# 3579846848                                         323.544250
# 3579846849                                         323.547241
# 3579846850                                         323.550262
# 3579846851                                         323.553253
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_2/Sbedrock_mean  \
# 720603040                                           21.920830
# 720603041                                           21.935978
# 720603042                                           21.951126
# 720603043                                           21.966274
# 720603044                                           21.981422
# ...                                                       ...
# 3579846847                                          37.048393
# 3579846848                                          37.073277
# 3579846849                                          37.098156
# 3579846850                                          37.123039
# 3579846851                                          37.147923
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_3/Sbedrock_mean
# 720603040                                           63.699451
# 720603041                                           63.849354
# 720603042                                           63.999256
# 720603043                                           64.149162
# 720603044                                           64.299065
# ...                                                       ...
# 3579846847                                         173.493454
# 3579846848                                         173.518997
# 3579846849                                         173.544525
# 3579846850                                         173.570068
# 3579846851                                         173.595612
#
# [62008624 rows x 7 columns]

# %%
df = pd.DataFrame()

with nc.Dataset(f'Sbedrock.nc4') as dataset:
    lat = dataset['lat'][:].flatten()
    lon = dataset['lon'][:].flatten()
    df['lat'] = np.repeat(lat, len(lon))
    df['lon'] = np.tile(lon, len(lat))

file_variable_list = [
    (f'mask123', 'Band1'),
    (f'Sbedrock', 'Sbedrock'),
    (f'Area', 'area'),

    (f'{path1}Ssoil_mean', 'Sr'),
    (f'{path2}Ssoil_mean', 'Sr'),
    (f'{path3}Ssoil_mean', 'Sr'),
    (f'Ssoil', 'Band1'),
]

for entry in file_variable_list:
    file = entry[0]
    variable_name = entry[1]  
    index = entry[2:] if len(entry) > 2 else None  
    if index:
        df[file] = load_and_flatten_data(file, variable_name, index[0])
    else:
        df[file] = load_and_flatten_data(file, variable_name)


df = df.dropna()
df = df[df['Sbedrock'] > 0]
df = df[df['mask123'] == 1]
df.drop(labels='mask123',axis=1,inplace=True)
df.drop(labels='Sbedrock',axis=1,inplace=True)

print(df[f'{path1}Ssoil_mean'].mean())
print(df[f'{path2}Ssoil_mean'].mean())
print(df[f'{path3}Ssoil_mean'].mean())
print(df['Ssoil'].mean())

with open(f'csv/Global_cases_ss.csv','w') as f:
    df.to_csv(f)
df
# Out:
# 192.2227
# 128.89513
# 146.11655
# 91.70262
#                   lat        lon           Area  \
# 709889414  -55.764582 -67.439577  120773.879698
# 709889415  -55.764582 -67.435411  120773.879698
# 709889416  -55.764582 -67.431244  120773.879698
# 709889417  -55.764582 -67.427077  120773.879698
# 709975814  -55.760415 -67.439577  120786.785891
# ...               ...        ...            ...
# 3586500782  82.960426 -26.739575   26309.225697
# 3586500783  82.960426 -26.735409   26309.225697
# 3586500784  82.960426 -26.731242   26309.225697
# 3586500785  82.960426 -26.727075   26309.225697
# 3586500786  82.960426 -26.722909   26309.225697
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_1/Ssoil_mean  \
# 709889414                                           13.938974
# 709889415                                           19.511423
# 709889416                                           25.083874
# 709889417                                           30.656322
# 709975814                                           14.618910
# ...                                                       ...
# 3586500782                                           0.000000
# 3586500783                                           0.000000
# 3586500784                                           0.000000
# 3586500785                                           0.000000
# 3586500786                                           0.000000
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_2/Ssoil_mean  \
# 709889414                                            2.761799
# 709889415                                            3.865897
# 709889416                                            4.969995
# 709889417                                            6.074092
# 709975814                                            2.896518
# ...                                                       ...
# 3586500782                                           0.000000
# 3586500783                                           0.000000
# 3586500784                                           0.000000
# 3586500785                                           0.000000
# 3586500786                                           0.000000
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_3/Ssoil_mean  \
# 709889414                                            7.272129
# 709889415                                           10.179341
# 709889416                                           13.086555
# 709889417                                           15.993768
# 709975814                                            7.626859
# ...                                                       ...
# 3586500782                                           0.000000
# 3586500783                                           0.000000
# 3586500784                                           0.000000
# 3586500785                                           0.000000
# 3586500786                                           0.000000
#
#                  Ssoil
# 709889414     0.000000
# 709889415     0.000000
# 709889416   120.396660
# 709889417   120.416367
# 709975814     0.000000
# ...                ...
# 3586500782    0.000000
# 3586500783    0.000000
# 3586500784    0.000000
# 3586500785    0.000000
# 3586500786    0.000000
#
# [65805018 rows x 7 columns]

# %%
df = pd.DataFrame()

with nc.Dataset(f'Sbedrock.nc4') as dataset:
    lat = dataset['lat'][:].flatten()
    lon = dataset['lon'][:].flatten()
    df['lat'] = np.repeat(lat, len(lon))
    df['lon'] = np.tile(lon, len(lat))

file_variable_list = [
    (f'mask123', 'Band1'),
    (f'Sbedrock', 'Sbedrock'),
    (f'Area', 'area'),

    (f'{path1}Sr_mean', 'Sr'),
    (f'{path2}Sr_mean', 'Sr'),
    (f'{path3}Sr_mean', 'Sr'),
    (f'Sr', 'Sr'),
]

for entry in file_variable_list:
    file = entry[0]
    variable_name = entry[1]  
    index = entry[2:] if len(entry) > 2 else None  
    if index:
        df[file] = load_and_flatten_data(file, variable_name, index[0])
    else:
        df[file] = load_and_flatten_data(file, variable_name)


df = df.dropna()
df = df[df['Sbedrock'] > 0]
df = df[df['mask123'] == 1]
df.drop(labels='mask123',axis=1,inplace=True)
df.drop(labels='Sbedrock',axis=1,inplace=True)

print(df[f'{path1}Sr_mean'].mean())
print(df[f'{path2}Sr_mean'].mean())
print(df[f'{path3}Sr_mean'].mean())
print(df['Sr'].mean())

with open(f'csv/Global_cases_sr.csv','w') as f:
    df.to_csv(f)
df
# Out:
# 320.70575
# 160.65176
# 214.92178
# 217.62683
#                   lat        lon           Area  \
# 720603040  -55.247915 -67.331244  122369.355140
# 720603041  -55.247915 -67.327077  122369.355140
# 720603042  -55.247915 -67.322911  122369.355140
# 720603043  -55.247915 -67.318744  122369.355140
# 720603044  -55.247915 -67.314577  122369.355140
# ...               ...        ...            ...
# 3579846847  82.639592 -31.468742   27501.828156
# 3579846848  82.639592 -31.464576   27501.828156
# 3579846849  82.639592 -31.460409   27501.828156
# 3579846850  82.639592 -31.456242   27501.828156
# 3579846851  82.639592 -31.452076   27501.828156
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_1/Sr_mean  \
# 720603040                                          376.736206
# 720603041                                          377.508118
# 720603042                                          378.280060
# 720603043                                          379.051971
# 720603044                                          379.823883
# ...                                                       ...
# 3579846847                                         323.541229
# 3579846848                                         323.544250
# 3579846849                                         323.547241
# 3579846850                                         323.550262
# 3579846851                                         323.553253
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_2/Sr_mean  \
# 720603040                                           91.501808
# 720603041                                           91.365150
# 720603042                                           91.228493
# 720603043                                           91.091835
# 720603044                                           90.955177
# ...                                                       ...
# 3579846847                                          37.048393
# 3579846848                                          37.073277
# 3579846849                                          37.098156
# 3579846850                                          37.123039
# 3579846851                                          37.147923
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_3/Sr_mean  \
# 720603040                                          199.907684
# 720603041                                          200.288010
# 720603042                                          200.668335
# 720603043                                          201.048660
# 720603044                                          201.429001
# ...                                                       ...
# 3579846847                                         173.493454
# 3579846848                                         173.518997
# 3579846849                                         173.544525
# 3579846850                                         173.570068
# 3579846851                                         173.595612
#
#                     Sr
# 720603040   168.449478
# 720603041   164.875504
# 720603042   161.301544
# 720603043   157.727570
# 720603044   154.153610
# ...                ...
# 3579846847   33.762409
# 3579846848   33.865299
# 3579846849   33.968189
# 3579846850   34.071079
# 3579846851   34.173969
#
# [62008624 rows x 7 columns]

# %%
df = pd.DataFrame()

with nc.Dataset(f'Sbedrock.nc4') as dataset:
    lat = dataset['lat'][:].flatten()
    lon = dataset['lon'][:].flatten()
    df['lat'] = np.repeat(lat, len(lon))
    df['lon'] = np.tile(lon, len(lat))

file_variable_list = [
    (f'mask123', 'Band1'),
    (f'Sbedrock', 'Sbedrock'),
    (f'Area', 'area'),

    (f'{path1}rnof_mean', 'f_rnof'),
    (f'{path2}rnof_mean', 'f_rnof'),
    (f'{path3}rnof_mean', 'f_rnof'),

    (f'{path1}fevpa_mean', 'f_fevpa'),
    (f'{path2}fevpa_mean', 'f_fevpa'),
    (f'{path3}fevpa_mean', 'f_fevpa'),
    (f'Q_mean', 'tp', 0),
    (f'ET_mean', 'et', 0),
]

for entry in file_variable_list:
    file = entry[0]
    variable_name = entry[1]  
    index = entry[2:] if len(entry) > 2 else None  

    # print(f"File: {file}, Variable: {variable_name}, Index: {index}")
    if index:
        df[file] = load_and_flatten_data(file, variable_name, index[0])
    else:
        df[file] = load_and_flatten_data(file, variable_name)


df = df.dropna()
df = df[df['Sbedrock'] > 0]
df = df[df['mask123'] == 1]
df.drop(labels='mask123',axis=1,inplace=True)


print(df[f'{path1}rnof_mean'].mean())
print(df[f'{path2}rnof_mean'].mean())
print(df[f'{path3}rnof_mean'].mean())
print(df[f'{path1}fevpa_mean'].mean())
print(df[f'{path2}fevpa_mean'].mean())
print(df[f'{path3}fevpa_mean'].mean())
print(df['Q_mean'].mean())
print(df['ET_mean'].mean())

with open(f'csv/Global_cases_runoff_et.csv','w') as f:
    df.to_csv(f)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 34
#      32         df[file] = load_and_flatten_data(file, variable_name, index[0])
#      33     else:
# ---> 34         df[file] = load_and_flatten_data(file, variable_name)
#      37 df = df.dropna()
#      38 df = df[df['Sbedrock'] > 0]
#
# File ~/anaconda3/lib/mylib/myfunc.py:22, in load_and_flatten_data(file_name, variable_name, index)
#      21 def load_and_flatten_data(file_name, variable_name, index=None):
# ---> 22     with nc.Dataset(f"{file_name}.nc4") as dataset:
#      23         if index is not None:
#      24             data = dataset[variable_name][index, :, :].flatten()
#
# File src/netCDF4/_netCDF4.pyx:2463, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2026, in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'/tera11/zhwei/students/Xionghui/data/run/0p1//cases/bedrock_1/rnof_mean.nc4'
