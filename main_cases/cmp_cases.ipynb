# %%
import os
import numpy as np
import xarray as xr
import pandas as pd
import netCDF4 as nc
import geopandas as gpd
import rioxarray as rxr
from myfunc import timer
from myfunc import DirMan
from myfunc import load_and_flatten_data
import config

resolution     = config.resolution
region         = config.region
data_path      = config.data_path
post_data_path = config.post_data_path
shp_path       = config.shp_path
fig_path       = config.fig_path

dir_man = DirMan(data_path)
dir_man.enter()

os.makedirs(f'{data_path}/csv', exist_ok=True)

casename1 = 'bedrock_1'
path1 = f'{data_path}/cases/{casename1}/'
casename2 = 'bedrock_2'
path2 = f'{data_path}/cases/{casename2}/'
casename3 = 'bedrock_3'
path3 = f'{data_path}/cases/{casename3}/'
# Out:
# Entered /tera11/zhwei/students/Xionghui/data/run/500/

# %%
df = pd.DataFrame()

with nc.Dataset(f'Sbedrock.nc4') as dataset:
    lat = dataset['lat'][:].flatten()
    lon = dataset['lon'][:].flatten()
    df['lat'] = np.repeat(lat, len(lon))
    df['lon'] = np.tile(lon, len(lat))

file_variable_list = [
    (f'mask123', 'Band1'),
    (f'Sbedrock', 'Sbedrock'),
    (f'Area', 'area'),

    (f'{path1}Sr_mean', 'Sr'),
    (f'{path2}Sr_mean', 'Sr'),
    (f'{path3}Sr_mean', 'Sr'),
    (f'Sr', 'Sr'),
    (f'Ssoil', 'Band1'),

    # (f'{path1}Sr_mean', 'f_rootr'),
    # (f'{path2}Sr_mean', 'f_rootr'),
    # (f'{path3}Sr_mean', 'f_rootr'),

    # (f'{path1}PSr_mean', 'f_vegwp'),
    # (f'{path2}PSr_mean', 'f_vegwp'),
    # (f'{path3}PSr_mean', 'f_vegwp'),
]

for entry in file_variable_list:
    file = entry[0]
    variable_name = entry[1]  
    index = entry[2:] if len(entry) > 2 else None  

    # print(f"File: {file}, Variable: {variable_name}, Index: {index}")
    if index:
        df[file] = load_and_flatten_data(file, variable_name, index[0])
    else:
        df[file] = load_and_flatten_data(file, variable_name)


df = df.dropna()
df = df[df['Sbedrock'] > 0]
df = df[df['mask123'] == 1]
df.drop(labels='mask123',axis=1,inplace=True)

# print((df.groupby('D_FM_median')['Area'].sum()/1e12)/16.092963536896)
# print(df['Sbedrock'].mean())

print(df[f'{path1}Sr_mean'].mean())
print(df[f'{path2}Sr_mean'].mean())
print(df[f'{path3}Sr_mean'].mean())
print(df['Sr'].mean())
print(df['Ssoil'].mean())

# print(df[f'{path1}Sr_mean'].mean())
# print(df[f'{path2}Sr_mean'].mean())
# print(df[f'{path3}Sr_mean'].mean())

# print(df[f'{path1}PSr_mean'].mean())
# print(df[f'{path2}PSr_mean'].mean())
# print(df[f'{path3}PSr_mean'].mean())

with open(f'csv/Global_cases.csv','w') as f:
    df.to_csv(f)
df

# %%
df = pd.DataFrame()

with nc.Dataset(f'Sbedrock.nc4') as dataset:
    lat = dataset['lat'][:].flatten()
    lon = dataset['lon'][:].flatten()
    df['lat'] = np.repeat(lat, len(lon))
    df['lon'] = np.tile(lon, len(lat))

file_variable_list = [
    (f'mask123', 'Band1'),
    (f'Sbedrock', 'Sbedrock'),
    (f'Area', 'area'),

    (f'{path1}rnof_mean', 'f_rnof'),
    (f'{path2}rnof_mean', 'f_rnof'),
    (f'{path3}rnof_mean', 'f_rnof'),

    (f'{path1}fevpa_mean', 'f_fevpa'),
    (f'{path2}fevpa_mean', 'f_fevpa'),
    (f'{path3}fevpa_mean', 'f_fevpa'),
    (f'Q_mean', 'tp', 0),
    (f'ET_mean', 'et', 0),
]

for entry in file_variable_list:
    file = entry[0]
    variable_name = entry[1]  
    index = entry[2:] if len(entry) > 2 else None  

    # print(f"File: {file}, Variable: {variable_name}, Index: {index}")
    if index:
        df[file] = load_and_flatten_data(file, variable_name, index[0])
    else:
        df[file] = load_and_flatten_data(file, variable_name)


df = df.dropna()
df = df[df['Sbedrock'] > 0]
df = df[df['mask123'] == 1]
df.drop(labels='mask123',axis=1,inplace=True)


print(df[f'{path1}rnof_mean'].mean())
print(df[f'{path2}rnof_mean'].mean())
print(df[f'{path3}rnof_mean'].mean())
print(df[f'{path1}fevpa_mean'].mean())
print(df[f'{path2}fevpa_mean'].mean())
print(df[f'{path3}fevpa_mean'].mean())
print(df['Q_mean'].mean())
print(df['ET_mean'].mean())

with open(f'csv/Global_cases_runoff_et.csv','w') as f:
    df.to_csv(f)
df
# Out:
# 210.03174
# 482.5725
# 224.14845
# 721.1685
# 571.0068
# 688.8129
# 412.127
# 787.78766
#                   lat        lon   Sbedrock           Area  \
# 709889414  -55.764582 -67.439577   7.599648  120773.879698
# 709889415  -55.764582 -67.435411   6.355453  120773.879698
# 709889416  -55.764582 -67.431244   5.111259  120773.879698
# 709889417  -55.764582 -67.427077   3.867064  120773.879698
# 709975814  -55.760415 -67.439577   7.970362  120786.785891
# ...               ...        ...        ...            ...
# 3586500782  82.960426 -26.739575  39.297733   26309.225697
# 3586500783  82.960426 -26.735409  39.880871   26309.225697
# 3586500784  82.960426 -26.731242  40.464008   26309.225697
# 3586500785  82.960426 -26.727075  41.047146   26309.225697
# 3586500786  82.960426 -26.722909  41.630283   26309.225697
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_1/rnof_mean  \
# 709889414                                           22.061260
# 709889415                                           30.883379
# 709889416                                           39.705494
# 709889417                                           48.527615
# 709975814                                           23.137417
# ...                                                       ...
# 3586500782                                          10.514077
# 3586500783                                          14.716483
# 3586500784                                          18.918890
# 3586500785                                          23.121296
# 3586500786                                          27.323702
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_2/rnof_mean  \
# 709889414                                           60.588024
# 709889415                                           84.816681
# 709889416                                          109.045334
# 709889417                                          133.273987
# 709975814                                           63.543530
# ...                                                       ...
# 3586500782                                          10.773910
# 3586500783                                          15.080170
# 3586500784                                          19.386429
# 3586500785                                          23.692688
# 3586500786                                          27.998949
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_3/rnof_mean  \
# 709889414                                           17.772104
# 709889415                                           24.879025
# 709889416                                           31.985943
# 709889417                                           39.092861
# 709975814                                           18.639034
# ...                                                       ...
# 3586500782                                          10.624814
# 3586500783                                          14.871482
# 3586500784                                          19.118149
# 3586500785                                          23.364817
# 3586500786                                          27.611483
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_1/fevpa_mean  \
# 709889414                                           87.688011
# 709889415                                          122.753723
# 709889416                                          157.819443
# 709889417                                          192.885162
# 709975814                                           91.965462
# ...                                                       ...
# 3586500782                                           6.449410
# 3586500783                                           9.027196
# 3586500784                                          11.604982
# 3586500785                                          14.182768
# 3586500786                                          16.760553
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_2/fevpa_mean  \
# 709889414                                           73.080605
# 709889415                                          102.304939
# 709889416                                          131.529282
# 709889417                                          160.753616
# 709975814                                           76.645500
# ...                                                       ...
# 3586500782                                           6.217391
# 3586500783                                           8.702441
# 3586500784                                          11.187490
# 3586500785                                          13.672540
# 3586500786                                          16.157589
#
#             /tera11/zhwei/students/Xionghui/data/run/500//cases/bedrock_3/fevpa_mean  \
# 709889414                                           87.459503
# 709889415                                          122.433846
# 709889416                                          157.408188
# 709889417                                          192.382523
# 709975814                                           91.725807
# ...                                                       ...
# 3586500782                                           6.365170
# 3586500783                                           8.909286
# 3586500784                                          11.453403
# 3586500785                                          13.997519
# 3586500786                                          16.541636
#
#                 Q_mean     ET_mean
# 709889414   533.591919  486.263611
# 709889415   533.237976  485.323425
# 709889416   532.884033  484.383270
# 709889417   532.530090  483.443115
# 709975814   521.872864  509.983704
# ...                ...         ...
# 3586500782   17.907982  107.267189
# 3586500783   17.728516  107.503296
# 3586500784   17.549042  107.739403
# 3586500785   17.369576  107.975510
# 3586500786   17.190102  108.211624
#
# [116037061 rows x 12 columns]
