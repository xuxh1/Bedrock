# %%
# %matplotlib inline

import os
import cmaps
import salem
import numpy as np
import pandas as pd
import xarray as xr
import geopandas as gpd
from pylab import rcParams
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.patches as mpatches
from matplotlib.gridspec import GridSpec
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from myfunc import timer
from myfunc import DirMan
import config
import matplotlib.font_manager as fm
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
# configuration
# resolution = "0p1"
resolution = "500"
region = [-180,180,-60,90]
data_path = f'/tera04/zhwei/xionghui/bedrock/run/{resolution}/'
post_data_path = '/tera04/zhwei/xionghui/bedrock/'
shp_path = '/tera04/zhwei/xionghui/bedrock/Shp/'
fig_path = f'/home/xuxh22/stu01/Bedrock/fig/{resolution}/'
path = '/home/xuxh22/stu01/Bedrock/'
if resolution == "0p1":
    size = 0.1
elif resolution == "500":
    size = 0.0005

print('python draw_g2_scatter.py')
print(data_path)
# dir_man = DirMan(data_path)
# dir_man.enter()
os.makedirs(f'{fig_path}/global_map_2', exist_ok=True)

shp = gpd.GeoDataFrame.from_file(shp_path+'World_CN/ne_10m_admin_0_countries_chn.shp')

pd.set_option('display.max_columns', None)
# font = {'family': 'Times New Roman'}
font = {'family': 'Arial'}
mpl.rc('font', **font)

params = {'backend': 'ps',
          'axes.labelsize': 25,
          'axes.linewidth': 2,
          'grid.linewidth': 0.2,
          'font.size': 25,
          'legend.fontsize': 18,
          'legend.frameon': False,
          'xtick.labelsize': 30,
          'xtick.direction': 'out',
          'ytick.labelsize': 30,
          'ytick.direction': 'out',
          'legend.handlelength': 1,
          'legend.handleheight': 1,
          'savefig.bbox': 'tight',
          'axes.unicode_minus': False,
          "mathtext.default":"regular",
          'text.usetex': False}
rcParams.update(params)

font_properties = fm.FontProperties(weight='bold')
# Out:
# python draw_g2_scatter.py
# /tera04/zhwei/xionghui/bedrock/run/500/

# %%
fig = plt.figure(figsize=(7.2, 5))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(0)

# legend_labels = ['Pattern1—Bedrock water withdrawn \nevery year from 2003 to 2020', 
#                     'Pattern2—Bedrock water withdrawn \nsome year(s) from 2003 to 2020', ]
                    # 'Pattern3—Bedrock water not needed to \nexplain ET over course of study']
                    # 'Bedrock water use may occur, but \ncriteria for calculation are not met']
                    # 'Note classified as woody \nvegetation on shallow bedrock']
legend_labels = ['Pattern1 — using bedrock water \nevery year from 2003 to 2020', 
                    'Pattern2 — using bedrock water \nin certain year(s) from 2003 to 2020', ]
# rgb_list = ['#69aa4c','#CC0000','#ebc874']
rgb_list = ['#CC0000','#69aa4c',]


legend_elements = [
    Patch(facecolor=rgb_list[i], linewidth=3, edgecolor='black', label=legend_labels[i]) for i in range(2)
]

legend = ax.legend(
    handles=legend_elements,
    loc='lower left',
    frameon=False,
    title='',
    handlelength=2, 
    handleheight=2,
    handletextpad=0.5,  
    labelspacing= 1,
    prop={ "size":24}
)
ax.add_artist(legend)
fig.patch.set_alpha(0)
plt.tight_layout()
plt.savefig(f"/home/xuxh22/stu01/Bedrock/fig/all/fig3_legend.eps",dpi=500, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(18,7))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(0)

# legend_labels = ['Pattern1 — Bedrcok water withdrawn every year from 2003 to 2020', 
#                     'Pattern2 — Bedrcok water withdrawn some year(s) from 2003 to 2020', 
                    # 'Pattern3—Bedrcok water not needed to explain ET over course of study']
                    # 'Bedrock water use may occur, but \ncriteria for calculation are not met']
                    # 'Note classified as woody \nvegetation on shallow bedrock']
legend_labels = ['Pattern1 — using bedrock water every year from 2003 to 2020', 
                    'Pattern2 — using bedrock water in certain year(s) from 2003 to 2020', ]
# rgb_list = ['#69aa4c','#CC0000','#ebc874']
rgb_list = ['#CC0000','#69aa4c',]

legend_elements = [
    Patch(facecolor=rgb_list[i], linewidth=3, edgecolor='black', label=legend_labels[i]) for i in range(2)
]

legend = ax.legend(
    handles=legend_elements,
    loc='lower left',
    frameon=False,
    title='',
    handlelength=2, 
    handleheight=2,
    handletextpad=0.5,  
    labelspacing= 1,
    prop={ "size":24}
)
ax.add_artist(legend)
fig.patch.set_alpha(0)
plt.tight_layout()
plt.savefig(f"/home/xuxh22/stu01/Bedrock/fig/all/edf2_legend.eps",dpi=500, bbox_inches='tight')
plt.show()

# %%
fig = plt.figure(figsize=(15, 9))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
for spine in ax.spines.values():
    # spine.set_edgecolor('black')  
    spine.set_linewidth(0)

# legend_labels = ['Pattern1—Bedrock water withdrawn \nevery year from 2003 to 2020', 
#                     'Pattern2—Bedrock water withdrawn \nsome year(s) from 2003 to 2020', ]
                    # 'Pattern3—Bedrock water not needed to \nexplain ET over course of study']
                    # 'Bedrock water use may occur, but \ncriteria for calculation are not met']
                    # 'Note classified as woody \nvegetation on shallow bedrock']
legend_labels = ['Exp1: base', 
                'Exp2: 0.1 times',
                'Exp3: 0.5 times',
                'Exp1 - Exp2',
                'Exp1 - Exp3',
                'Exp2 - Exp3']

rgb_list = ['#4f83ae','#f0734d', '#dbb355','#75ae6c', '#b16e45','#8f2887']


legend_elements = [
    Line2D([0], [0], color=rgb_list[i], linewidth=4, linestyle='-', label=legend_labels[i]) for i in range(3)
] + [
    Line2D([0], [0], color='none', linewidth=0, linestyle='-', label='')  # 空白行
] + [
    Line2D([0], [0], color=rgb_list[i], linewidth=4, linestyle='-', label=legend_labels[i]) for i in range(3, 6)
]

legend = ax.legend(
    handles=legend_elements,
    loc='lower left',
    frameon=False,
    title='',
    handlelength=2, 
    handleheight=1.5,
    handletextpad=0.5,  
    labelspacing= 1,
    prop={ "size":32}
)
ax.add_artist(legend)
# fig.patch.set_alpha(0)
plt.tight_layout()
plt.savefig(f"/home/xuxh22/stu01/Bedrock/fig/all/fig4_legend.eps",dpi=500, bbox_inches='tight')
plt.show()
