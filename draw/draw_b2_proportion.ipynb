# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from plotnine import *
from pylab import rcParams
import matplotlib

font = {'family': 'Times New Roman'}
matplotlib.rc('font', **font)
df = pd.read_csv('/tera11/zhwei/students/Xionghui/data/run/0p1_exp1/csv/Global_proportion.csv')
df
# Out:
#         Unnamed: 0    lat    lon    Sbedrock  mask123  Dbedrock_Frequency  \
# 0          1243113 -55.45 -68.65  834.754800      1.0                 2.0
# 1          1250334 -55.25 -66.55    9.669006      1.0                 2.0
# 2          1253920 -55.15 -67.95  195.114100      1.0                 2.0
# 3          1253921 -55.15 -67.85   57.865448      1.0                 2.0
# 4          1261124 -54.95 -67.55    0.797073      1.0                 2.0
# ...            ...    ...    ...         ...      ...                 ...
# 204468     5960778  75.55  97.85   18.478424      1.0                 3.0
# 204469     5964321  75.65  92.15   20.923874      1.0                 3.0
# 204470     5964353  75.65  95.35   52.938347      1.0                 3.0
# 204471     5967959  75.75  95.95   32.156340      1.0                 3.0
# 204472     5967965  75.75  96.55   47.179880      1.0                 3.0
#
#         Proportion/Proportion1  Proportion/Proportion2_median  \
# 0                    93.044620                     189.341540
# 1                    12.469337                       1.831706
# 2                    66.786290                      45.559517
# 3                    38.287674                      14.075084
# 4                     1.187136                       0.171270
# ...                        ...                            ...
# 204468               11.587280                      10.615145
# 204469               14.052288                      11.213067
# 204470               30.074024                      30.300247
# 204471               19.821024                      17.602580
# 204472               27.575737                      26.311249
#
#         Proportion/Proportion3_median  Proportion/Proportion4_median  \
# 0                           66.318310                      33.952110
# 1                           40.332560                      59.508057
# 2                           52.560856                      47.404076
# 3                           52.925420                      47.439137
# 4                           24.528934                      76.369560
# ...                               ...                            ...
# 204468                      48.869823                      50.150814
# 204469                      42.112606                      59.442630
# 204470                      50.306892                      49.897938
# 204471                      46.762650                      52.616790
# 204472                      49.347250                      50.394190
#
#         Proportion/Proportion5_median  Proportion/Proportion6_median  \
# 0                           64.285446                     -30.333336
# 1                            1.090012                      58.418045
# 2                           21.597067                      25.807009
# 3                            6.677098                      40.762040
# 4                            0.130798                      76.238760
# ...                               ...                            ...
# 204468                       5.323581                      44.827232
# 204469                       6.665342                      52.777290
# 204470                      15.119199                      34.778740
# 204471                       9.261911                      43.354880
# 204472                      13.259341                      37.134850
#
#         Proportion/Proportion7_median
# 0                           30.554195
# 1                           56.394520
# 2                           50.889477
# 3                           48.636920
# 4                           94.110245
# ...                               ...
# 204468                      69.359390
# 204469                      75.018990
# 204470                      65.045430
# 204471                      64.662186
# 204472                      60.914997
#
# [204473 rows x 13 columns]

# %%
print(df["Proportion/Proportion1"].mean())
print(df["Proportion/Proportion2_median"].mean())
print(df["Proportion/Proportion3_median"].mean())
print(df["Proportion/Proportion4_median"].mean())
print(df["Proportion/Proportion5_median"].mean())
print(df["Proportion/Proportion6_median"].mean())
print(df["Proportion/Proportion7_median"].mean())
# Out:
# 52.689652227662336
# 25.84495830685234
# 32.767179011929684
# 67.21341480546576
# 15.327635019532867
# 51.88577977439334
# 145.58030772218336

# %%
df1 = pd.read_csv('/tera11/zhwei/students/Xionghui/data/run/0p1_exp1/csv/Global_partition.csv')
df1
# Out:
#         Unnamed: 0    lat    lon    Sbedrock  mask123         DTB         ET  \
# 0          1243113 -55.45 -68.65  834.754800      1.0   49.860622  440.46620
# 1          1250334 -55.25 -66.55    9.669006      1.0   49.949530  528.49780
# 2          1253920 -55.15 -67.95  195.114100      1.0   74.904630  429.83832
# 3          1253921 -55.15 -67.85   57.865448      1.0   75.095290  411.36050
# 4          1261124 -54.95 -67.55    0.797073      1.0   50.050095  466.50153
# ...            ...    ...    ...         ...      ...         ...        ...
# 204510     5960778  75.55  97.85   18.478424      1.0  100.000000  174.30890
# 204511     5964321  75.65  92.15   20.923874      1.0  100.000000  186.58446
# 204512     5964353  75.65  95.35   52.938347      1.0  100.000000  174.72653
# 204513     5967959  75.75  95.95   32.156340      1.0  100.000000  183.85385
# 204514     5967965  75.75  96.55   47.179880      1.0  100.000000  178.56912
#
#                 PR           Q         LH         FY   FM_mean
# 0       1302.72950  862.263300  59.742570  -0.998749 -0.998057
# 1        864.09620  335.598400   0.692001  -1.000000 -1.000000
# 2        870.53050  440.692200  13.964122  -1.000000 -1.000000
# 3        841.86560  430.505100   4.141372  -1.000000 -1.000000
# 4        610.79364  144.292110   0.057046  16.000000  1.000000
# ...            ...         ...        ...        ...       ...
# 204510   338.62622  164.317320   1.322482  -1.000000 -1.000000
# 204511   309.19412  122.609665   1.497501  -1.000000 -1.000000
# 204512   343.87106  169.144530   3.788745  -1.000000 -1.000000
# 204513   339.60202  155.748170   2.301397  -1.000000 -1.000000
# 204514   346.41490  167.845760   3.376617  -1.000000 -1.000000
#
# [204515 rows x 12 columns]

# %%
print(df1["ET"].mean())
print(df1["Sbedrock"].mean())
# Out:
# 680.1950617163042
# 161.6725811692714

# %%
df['Dbedrock_Frequency'] = df['Dbedrock_Frequency'].astype('int64')
n1 = len(df[df['Dbedrock_Frequency']==1])
n2 = len(df[df['Dbedrock_Frequency']==2])
n3 = len(df[df['Dbedrock_Frequency']==3])
print(n1,n2,n3)
n = [n1,n2,n3]

df['Dbedrock_Frequency'] = df['Dbedrock_Frequency'].astype(str)
df = df[df['Dbedrock_Frequency'] != '4']

df
# print(df['Dbedrock_Frequency'].describe())

size1 = 30
size2 = 24

df['Dbedrock_Frequency'] = pd.Categorical(df['Dbedrock_Frequency'], categories=["1", "2", "3"], ordered=True)
# Out:
# 43418 137942 23031
# /tmp/ipykernel_1737244/4121522936.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
fig = plt.figure(figsize=(18, 8))
sns.boxenplot(x="Dbedrock_Frequency", y="Proportion/Proportion1", data=df, linewidth=3,
              hue='Dbedrock_Frequency',palette=sns.husl_palette(4, s=0.90, l=0.65, h=0.0417))
                
ax = plt.gca()

ax.tick_params(axis='x', which='major', length=10, width=2, direction='out')
ax.tick_params(axis='y', which='major', length=10, width=2, direction='out')

for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(3)  

for i, label in enumerate(ax.get_xticklabels()):
    x_pos = label.get_position()[0]
    ax.text(x_pos+0.3, 85, f'{n[i]}', ha='center', va='bottom', fontsize=size1, fontweight='bold', color='black')

plt.ylim(0, 100)


plt.xlabel('')  
plt.ylabel("Percentage of root-zone water storage \ncapacity accomodated by bedrock \n($S_{bedrock}$/$S_{r}$)", fontsize=size1, fontweight='bold')  

current_ticks = [0,1,2]

new_labels = ['Bedrcok water \nwithdrawn every year \nfrom 2003 to 2020', 
                        'Bedrcok water \nwithdrawn some year(s) \nfrom 2003 to 2020', 
                        'Bedrcok water \nnot needed to explain ET \nover course of study']

plt.xticks(ticks=current_ticks, labels=new_labels, fontsize=size1, fontweight='bold')

yticks = np.arange(0, 120, 20)
plt.yticks(ticks=yticks, labels=yticks,fontsize=size1, fontweight='bold')

# fig.savefig('boxenplot2.pdf')
# Out:
# /tmp/ipykernel_1737244/2527846866.py:2: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
# ([<matplotlib.axis.YTick at 0x14d6e91782e0>,
#   <matplotlib.axis.YTick at 0x14d6e912fb50>,
#   <matplotlib.axis.YTick at 0x14d6e917bc10>,
#   <matplotlib.axis.YTick at 0x14d6e916c3d0>,
#   <matplotlib.axis.YTick at 0x14d6e92102e0>,
#   <matplotlib.axis.YTick at 0x14d6e9210760>],
#  [Text(0, 0, '0'),
#   Text(0, 20, '20'),
#   Text(0, 40, '40'),
#   Text(0, 60, '60'),
#   Text(0, 80, '80'),
#   Text(0, 100, '100')])

# %%
fig = plt.figure(figsize=(18, 8))
sns.boxenplot(x="Dbedrock_Frequency", y="Proportion/Proportion2_median", data=df, linewidth=3,
              hue='Dbedrock_Frequency',palette=sns.husl_palette(4, s=0.90, l=0.65, h=0.0417))
                
ax = plt.gca()

ax.tick_params(axis='x', which='major', length=10, width=2, direction='out')
ax.tick_params(axis='y', which='major', length=10, width=2, direction='out')

for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(3)  

for i, label in enumerate(ax.get_xticklabels()):
    x_pos = label.get_position()[0]
    ax.text(x_pos+0.3, 85, f'{n[i]}', ha='center', va='bottom', fontsize=size1, fontweight='bold', color='black')

plt.ylim(0, 100)


plt.xlabel('')  
plt.ylabel("Proportion of annual ET sourced \n from $S_{bedrock}$", fontsize=size1, fontweight='bold')  

current_ticks = [0,1,2]

new_labels = ['Bedrcok water \nwithdrawn every year \nfrom 2003 to 2020', 
                        'Bedrcok water \nwithdrawn some year(s) \nfrom 2003 to 2020', 
                        'Bedrcok water \nnot needed to explain ET \nover course of study']

plt.xticks(ticks=current_ticks, labels=new_labels, fontsize=size1, fontweight='bold')

yticks =np.linspace(0,100,6).astype('int64')
plt.yticks(ticks=yticks,labels=yticks,fontsize=size1, fontweight='bold')
# Out:
# /tmp/ipykernel_1737244/2024345265.py:2: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
# ([<matplotlib.axis.YTick at 0x14d6e937a0e0>,
#   <matplotlib.axis.YTick at 0x14d6e939e0b0>,
#   <matplotlib.axis.YTick at 0x14d6e92b1990>,
#   <matplotlib.axis.YTick at 0x14d6e9379ae0>,
#   <matplotlib.axis.YTick at 0x14d6e92b1330>,
#   <matplotlib.axis.YTick at 0x14d6e912e290>],
#  [Text(0, 0, '0'),
#   Text(0, 20, '20'),
#   Text(0, 40, '40'),
#   Text(0, 60, '60'),
#   Text(0, 80, '80'),
#   Text(0, 100, '100')])

# %%
fig = plt.figure(figsize=(18, 8))
sns.boxenplot(x="Dbedrock_Frequency", y="Proportion/Proportion3_median", data=df, linewidth=3,
              hue='Dbedrock_Frequency',palette=sns.husl_palette(4, s=0.90, l=0.65, h=0.0417))
                
ax = plt.gca()

ax.tick_params(axis='x', which='major', length=10, width=2, direction='out')
ax.tick_params(axis='y', which='major', length=10, width=2, direction='out')

for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(3)  

for i, label in enumerate(ax.get_xticklabels()):
    x_pos = label.get_position()[0]
    ax.text(x_pos+0.3, 85, f'{n[i]}', ha='center', va='bottom', fontsize=size1, fontweight='bold', color='black')

plt.ylim(0, 100)


plt.xlabel('')  
plt.ylabel("Q/PR", fontsize=size1, fontweight='bold')  

current_ticks = [0,1,2]

new_labels = ['Bedrcok water \nwithdrawn every year \nfrom 2003 to 2020', 
                        'Bedrcok water \nwithdrawn some year(s) \nfrom 2003 to 2020', 
                        'Bedrcok water \nnot needed to explain ET \nover course of study']

plt.xticks(ticks=current_ticks, labels=new_labels, fontsize=size1, fontweight='bold')

yticks =np.linspace(0,100,6).astype('int64')
plt.yticks(ticks=yticks,labels=yticks,fontsize=size1, fontweight='bold')
# Out:
# /tmp/ipykernel_1737244/3955257296.py:2: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
# ([<matplotlib.axis.YTick at 0x14d6e91e6c20>,
#   <matplotlib.axis.YTick at 0x14d6e91e66b0>,
#   <matplotlib.axis.YTick at 0x14d6e90f3580>,
#   <matplotlib.axis.YTick at 0x14d6e926b190>,
#   <matplotlib.axis.YTick at 0x14d6e90f03a0>,
#   <matplotlib.axis.YTick at 0x14d6e9036410>],
#  [Text(0, 0, '0'),
#   Text(0, 20, '20'),
#   Text(0, 40, '40'),
#   Text(0, 60, '60'),
#   Text(0, 80, '80'),
#   Text(0, 100, '100')])

# %%
fig = plt.figure(figsize=(18, 8))
sns.boxenplot(x="Dbedrock_Frequency", y="Proportion/Proportion4_median", data=df, linewidth=3,
              hue='Dbedrock_Frequency',palette=sns.husl_palette(4, s=0.90, l=0.65, h=0.0417))
                
ax = plt.gca()

ax.tick_params(axis='x', which='major', length=10, width=2, direction='out')
ax.tick_params(axis='y', which='major', length=10, width=2, direction='out')

for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(3)  

for i, label in enumerate(ax.get_xticklabels()):
    x_pos = label.get_position()[0]
    ax.text(x_pos+0.38, 88, f'{n[i]}', ha='center', va='bottom', fontsize=size1, fontweight='bold', color='black')

plt.ylim(0, 100)


plt.xlabel('')  
plt.ylabel("$ET_{median}$ / $PR_{median}$", fontsize=size1, fontweight='bold')  

current_ticks = [0,1,2]

new_labels = ['Bedrcok water \nwithdrawn every year \nfrom 2003 to 2020', 
                        'Bedrcok water \nwithdrawn some year(s) \nfrom 2003 to 2020', 
                        'Bedrcok water \nnot needed to explain ET \nover course of study']

plt.xticks(ticks=current_ticks, labels=new_labels, fontsize=size1, fontweight='bold')

yticks =np.linspace(0,100,6).astype('int64')
plt.yticks(ticks=yticks,labels=yticks,fontsize=size1, fontweight='bold')
# Out:
# /tmp/ipykernel_1737244/1134300968.py:2: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
# ([<matplotlib.axis.YTick at 0x14d6e8de64a0>,
#   <matplotlib.axis.YTick at 0x14d6e8edb880>,
#   <matplotlib.axis.YTick at 0x14d6e8d878b0>,
#   <matplotlib.axis.YTick at 0x14d6e8ffa770>,
#   <matplotlib.axis.YTick at 0x14d6e8d5d8d0>,
#   <matplotlib.axis.YTick at 0x14d6e8d5ee30>],
#  [Text(0, 0, '0'),
#   Text(0, 20, '20'),
#   Text(0, 40, '40'),
#   Text(0, 60, '60'),
#   Text(0, 80, '80'),
#   Text(0, 100, '100')])

# %%
fig = plt.figure(figsize=(18, 8))
sns.boxenplot(x="Dbedrock_Frequency", y="Proportion/Proportion5_median", data=df, linewidth=3,
              hue='Dbedrock_Frequency',palette=sns.husl_palette(4, s=0.90, l=0.65, h=0.0417))
                
ax = plt.gca()

ax.tick_params(axis='x', which='major', length=10, width=2, direction='out')
ax.tick_params(axis='y', which='major', length=10, width=2, direction='out')

for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(3)  

for i, label in enumerate(ax.get_xticklabels()):
    x_pos = label.get_position()[0]
    ax.text(x_pos+0.3, 85, f'{n[i]}', ha='center', va='bottom', fontsize=size1, fontweight='bold', color='black')

plt.ylim(0, 100)


plt.xlabel('')  
plt.ylabel("$S_{bedrock}$ / $PR_{median}$", fontsize=size1, fontweight='bold')  

current_ticks = [0,1,2]

new_labels = ['Bedrcok water \nwithdrawn every year \nfrom 2003 to 2020', 
                        'Bedrcok water \nwithdrawn some year(s) \nfrom 2003 to 2020', 
                        'Bedrcok water \nnot needed to explain ET \nover course of study']

plt.xticks(ticks=current_ticks, labels=new_labels, fontsize=size1, fontweight='bold')

yticks =np.linspace(0,100,6).astype('int64')
plt.yticks(ticks=yticks,labels=yticks,fontsize=size1, fontweight='bold')
# Out:
# /tmp/ipykernel_1737244/1103917179.py:2: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
# ([<matplotlib.axis.YTick at 0x14d6e8c04ee0>,
#   <matplotlib.axis.YTick at 0x14d6e8c04880>,
#   <matplotlib.axis.YTick at 0x14d6e8c4e380>,
#   <matplotlib.axis.YTick at 0x14d6e8c9b0a0>,
#   <matplotlib.axis.YTick at 0x14d6e8bd8c40>,
#   <matplotlib.axis.YTick at 0x14d6e8bd8610>],
#  [Text(0, 0, '0'),
#   Text(0, 20, '20'),
#   Text(0, 40, '40'),
#   Text(0, 60, '60'),
#   Text(0, 80, '80'),
#   Text(0, 100, '100')])

# %%
fig = plt.figure(figsize=(18, 8))
sns.boxenplot(x="Dbedrock_Frequency", y="Proportion/Proportion6_median", data=df, linewidth=3,
              hue='Dbedrock_Frequency',palette=sns.husl_palette(4, s=0.90, l=0.65, h=0.0417))
                
ax = plt.gca()

ax.tick_params(axis='x', which='major', length=10, width=2, direction='out')
ax.tick_params(axis='y', which='major', length=10, width=2, direction='out')

for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(3)  

for i, label in enumerate(ax.get_xticklabels()):
    x_pos = label.get_position()[0]
    ax.text(x_pos+0.3, 85, f'{n[i]}', ha='center', va='bottom', fontsize=size1, fontweight='bold', color='black')

plt.ylim(0, 100)


plt.xlabel('')  
plt.ylabel("($ET_{median}$ - $S_{bedrock}$) / $PR_{median}$", fontsize=size1, fontweight='bold')  

current_ticks = [0,1,2]

new_labels = ['Bedrcok water \nwithdrawn every year \nfrom 2003 to 2020', 
                        'Bedrcok water \nwithdrawn some year(s) \nfrom 2003 to 2020', 
                        'Bedrcok water \nnot needed to explain ET \nover course of study']

plt.xticks(ticks=current_ticks, labels=new_labels, fontsize=size1, fontweight='bold')

yticks =np.linspace(0,100,6).astype('int64')
plt.yticks(ticks=yticks,labels=yticks,fontsize=size1, fontweight='bold')
# Out:
# /tmp/ipykernel_1737244/1233376131.py:2: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
# ([<matplotlib.axis.YTick at 0x14d6e8a891e0>,
#   <matplotlib.axis.YTick at 0x14d6e8a88b80>,
#   <matplotlib.axis.YTick at 0x14d6e8b93100>,
#   <matplotlib.axis.YTick at 0x14d6e8cdee00>,
#   <matplotlib.axis.YTick at 0x14d6e8bc74c0>,
#   <matplotlib.axis.YTick at 0x14d6e8aacfa0>],
#  [Text(0, 0, '0'),
#   Text(0, 20, '20'),
#   Text(0, 40, '40'),
#   Text(0, 60, '60'),
#   Text(0, 80, '80'),
#   Text(0, 100, '100')])

# %%
fig = plt.figure(figsize=(18, 8))
sns.boxenplot(x="Dbedrock_Frequency", y="Proportion/Proportion7_median", data=df, linewidth=3,
              hue='Dbedrock_Frequency',palette=sns.husl_palette(4, s=0.90, l=0.65, h=0.0417))
                
ax = plt.gca()

ax.tick_params(axis='x', which='major', length=10, width=2, direction='out')
ax.tick_params(axis='y', which='major', length=10, width=2, direction='out')

for spine in ax.spines.values():
    spine.set_edgecolor('black')  
    spine.set_linewidth(3)  

for i, label in enumerate(ax.get_xticklabels()):
    x_pos = label.get_position()[0]
    ax.text(x_pos+0.3, 85, f'{n[i]}', ha='center', va='bottom', fontsize=size1, fontweight='bold', color='black')

plt.ylim(0, 100)


plt.xlabel('')  
plt.ylabel("PET / $PR_{median}$", fontsize=size1, fontweight='bold')  

current_ticks = [0,1,2]

new_labels = ['Bedrcok water \nwithdrawn every year \nfrom 2003 to 2020', 
                        'Bedrcok water \nwithdrawn some year(s) \nfrom 2003 to 2020', 
                        'Bedrcok water \nnot needed to explain ET \nover course of study']

plt.xticks(ticks=current_ticks, labels=new_labels, fontsize=size1, fontweight='bold')

yticks =np.linspace(0,100,6).astype('int64')
plt.yticks(ticks=yticks,labels=yticks,fontsize=size1, fontweight='bold')
# Out:
# /tmp/ipykernel_1737244/3393641721.py:2: UserWarning: The palette list has more values (4) than needed (3), which may not be intended.
# ([<matplotlib.axis.YTick at 0x14d6e8aaf7f0>,
#   <matplotlib.axis.YTick at 0x14d6e8aafca0>,
#   <matplotlib.axis.YTick at 0x14d6e8a11090>,
#   <matplotlib.axis.YTick at 0x14d6e8a10790>,
#   <matplotlib.axis.YTick at 0x14d6e8a10820>,
#   <matplotlib.axis.YTick at 0x14d6e8935900>],
#  [Text(0, 0, '0'),
#   Text(0, 20, '20'),
#   Text(0, 40, '40'),
#   Text(0, 60, '60'),
#   Text(0, 80, '80'),
#   Text(0, 100, '100')])
